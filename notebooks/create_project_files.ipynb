# %%
import pandas as pd
from pathlib import Path
import requests
import json

# %%
all_taxa =  Path('outputs', 'combine_taxa_list_inat_data.csv')

# %%
def log_df(df, nrows=5):
    print(df.shape)
    return df.head(nrows)

# %%
raw_data_paths = Path('../data').rglob('observations*.csv')
data_paths = [str(path) for path in raw_data_paths]
print(data_paths)
# Out:
# ['../data/clarkstown-high-school-north/observations-200303.csv', '../data/cedar-creek-reserve/observations-199064.csv', '../data/los-angeles-bioblitz/observations-190446.csv', '../data/ciencia-ciudadana-peru-bats/observations-199065.csv', '../data/ciencia-ciudadana-peru-bees/observations-199066.csv']

# %% [markdown]
# # create observation json

# %%
inat_ids_cols =['taxon_id', 'taxon_ids']
inat_ids_df = pd.read_csv(all_taxa, dtype=str, usecols=inat_ids_cols)
inat_ids_df['taxon_id'] = inat_ids_df['taxon_id'].astype(int)

inat_ids_df = inat_ids_df.fillna('')
log_df(inat_ids_df)
# Out:
# (3851, 2)
#    taxon_id                                   taxon_ids
# 0    143452     1|47120|47158|47157|47213|143454|143452
# 1     47727       47126|211194|47124|47729|58321|47727|
# 2     53178  47126|211194|47124|48151|50638|50636|53178
# 3     60307  47126|211194|47163|47162|47434|52809|60307
# 4     47124                      47126|211194|47124||||

# %%
all_cols = [
    'time_observed_at',
    'image_url',  
    'latitude', 
    'longitude',
    'user_login', 
    'scientific_name', 
    'common_name',
    'taxon_id',
    'id',
    'geoprivacy',
    'taxon_geoprivacy',
    'coordinates_obscured'
]

# %%
# combine multiple observations csvs for a project into one json         

for dir_path in Path().glob('../data/**/'):
    if dir_path.name != 'data':
        dfs = []
        for file_path in  Path().glob('../data/' + dir_path.name + '/observations*.csv'  ):
            print(file_path.name)
            df = pd.read_csv(file_path,  usecols=all_cols)
            df['taxon_id'].fillna(0, inplace=True)
            df['taxon_id'] = df['taxon_id'].astype(int)
            df = df.merge(inat_ids_df, on="taxon_id", how="left")
            
            # Safari won't parse dates in the format given by iNaturalist          
            df['time_observed_at'] = df['time_observed_at'].replace('([\d-]+) ([\d:]+) (UTC)', r'\1T\2Z', regex = True) 
            df['time_observed_at'] = df['time_observed_at'].replace('([\d-]+) ([\d:]+) -0700', r'\1T\2Z', regex = True) 

            dfs.append(df)
            
        combine_df = pd.concat(dfs)
        
        new_path = Path('..','inat_data_explorer', 'src', 'lib', 'data', dir_path.name)
        new_path.mkdir(parents=True, exist_ok=True)
        combine_df.to_json(new_path/ 'observations.json', orient = "records")
# Out:
# observations-200303.csv
# observations-199064.csv
# observations-190446.csv
# observations-199065.csv
# observations-199066.csv

# %% [markdown]
# # create taxa json and csv

# %% [markdown]
# inat_names_cols =['taxon_id', 'scientific_names', 'common_names', 'taxon_ids']
# inat_names_df = pd.read_csv(all_taxa, dtype=str, usecols=inat_names_cols)
# inat_names_df['taxon_id'] = inat_names_df['taxon_id'].astype(int)
# inat_names_df = inat_names_df.fillna('')
# log_df(inat_names_df)
#
#
# taxa_cols = [
#     'scientific_name',
#     'common_name',
#     'taxon_id',
#     'iconic_taxon_name',
#     'taxon_kingdom_name',
#     'taxon_phylum_name',
#     'taxon_class_name',
#     'taxon_order_name',
#     'taxon_family_name',
#     'taxon_genus_name',
#     'taxon_species_name',
# ]
# basic_taxa_cols = ['scientific_name', 'common_name', 'taxon_id']
#
# basic_cols = basic_taxa_cols + ['image_url', 'user_login']
# cols = taxa_cols + ['image_url', 'user_login']
#
#
#
# def create_taxa_df_v1(df):
#     df['taxon_id'] = df['taxon_id'].astype(int)
#
#     df['is_species'] = df['taxon_species_name'].notna()
#     adjust_is_species_for_higher_ranks_v1(df)
#
#     temp = df.copy()
#     temp['temp_count'] = 1
#     temp['temp_count'] = temp['temp_count'].astype(int)
#
#     # create a df with 2 columns: taxon_id and temp_count
#     count_df = temp.groupby(['taxon_id'])['temp_count'].sum().reset_index()
#     count_df.rename(columns={"temp_count": "count"}, inplace=True)
#
#
#     df = df.drop_duplicates(subset=['taxon_id'])
#     df = df.merge(count_df)
#     df = df.sort_values('count', ascending=False)
#
#     return df
#
#
# def adjust_is_species_for_higher_ranks_v1(df):
#     adjust_is_species_for_rank_v1(df, 'taxon_genus_name')
#     adjust_is_species_for_rank_v1(df, 'taxon_family_name')
#     adjust_is_species_for_rank_v1(df, 'taxon_order_name')
#     adjust_is_species_for_rank_v1(df, 'taxon_class_name')
#     adjust_is_species_for_rank_v1(df, 'taxon_phylum_name')
#     adjust_is_species_for_rank_v1(df, 'taxon_kingdom_name')
#     df.loc[df['scientific_name'].str.contains(' × ') == True, 'is_species'] = True
#
# def adjust_is_species_for_rank_v1(df, rank):
#     tmp = df.copy()
#     taxa = list(df[df['is_species'] == True][rank].unique())
#     tmp = tmp[(tmp['is_species'] == False) & (tmp[rank].notna())]
#     for index, row in tmp[~ tmp[rank].isin(taxa)].iterrows():
#         df.at[index, 'is_species'] = True
#
#
# for dir_path in Path().glob('../data/**/'):
#     if dir_path.name != 'data':
#         dfs = []
#         for file_path in  Path().glob('../data/' +  dir_path.name + '/observations-*.csv'  ):
#             df = pd.read_csv(file_path,  usecols=cols)
#             df = df.dropna(subset=['taxon_id'])
#             df['taxon_id'] = df['taxon_id'].astype(int)
#             df = df.merge(inat_names_df, on="taxon_id", how="left")
#
#
#             dfs.append(df)
#
#         combine_df = pd.concat(dfs)
#         taxa_df = create_taxa_df_v1(combine_df)
#
#         taxa_list_path = Path('..', 'data',  dir_path.name, 'taxa_list_v1.csv' )
#         taxa_df.to_csv(taxa_list_path, index=False)
#
#         new_path = Path('..','inat_data_explorer', 'src', 'lib', 'data') /dir_path.name
#         new_path.mkdir(parents=True, exist_ok=True)
#         basic_df = taxa_df[basic_cols + ['count', 'is_species', 'taxon_ids', 'scientific_names', 'common_names']]
#         basic_df.to_json(new_path/ "taxa_v1.json", orient = "records")

# %%
columns = []
ranks = ['kingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species']
[columns.append(rank + '_id') for rank in ranks]
[columns.append(rank + '_common_name') for rank in ranks]
columns = ['taxon_id', 'scientific_name', 'common_name',
           'rank', 
           'taxon_ids', 'scientific_names', 'common_names'] + ranks + columns 

inat_names_df = pd.read_csv(all_taxa, dtype=str, usecols=columns)
inat_names_df['taxon_id'] = inat_names_df['taxon_id'].astype(int)
log_df(inat_names_df)
# Out:
# (3851, 28)
#        scientific_name         common_name  taxon_id   kingdom        phylum  \
# 0  Deidamia inscriptum     Lettered Sphinx    143452  Animalia    Arthropoda
# 1                 Acer              maples     47727   Plantae  Tracheophyta
# 2  Plantago lanceolata    ribwort plantain     53178   Plantae  Tracheophyta
# 3        Poa pratensis  Kentucky bluegrass     60307   Plantae  Tracheophyta
# 4        Magnoliopsida              dicots     47124   Plantae  Tracheophyta
#
#            class        order          family     genus              species  \
# 0        Insecta  Lepidoptera      Sphingidae  Deidamia  Deidamia inscriptum
# 1  Magnoliopsida   Sapindales     Sapindaceae      Acer                  NaN
# 2  Magnoliopsida     Lamiales  Plantaginaceae  Plantago  Plantago lanceolata
# 3     Liliopsida       Poales         Poaceae       Poa        Poa pratensis
# 4  Magnoliopsida          NaN             NaN       NaN                  NaN
#
#    ... class_common_name order_id  \
# 0  ...           Insects    47157
# 1  ...            dicots    47729
# 2  ...            dicots    48151
# 3  ...          monocots    47162
# 4  ...            dicots      NaN
#
#                               order_common_name family_id family_common_name  \
# 0                         Butterflies and Moths     47213       Sphinx Moths
# 1  soapberries, cashews, mahoganies, and allies     58321   soapberry family
# 2          mints, plantains, olives, and allies     50638    plantain family
# 3         grasses, sedges, cattails, and allies     47434            grasses
# 4                                           NaN       NaN                NaN
#
#   genus_id genus_common_name                                   taxon_ids  \
# 0   143454               NaN     1|47120|47158|47157|47213|143454|143452
# 1    47727            maples       47126|211194|47124|47729|58321|47727|
# 2    50636          plantain  47126|211194|47124|48151|50638|50636|53178
# 3    52809    Meadow-grasses  47126|211194|47163|47162|47434|52809|60307
# 4      NaN               NaN                      47126|211194|47124||||
#
#                                     scientific_names  \
# 0  Animalia|Arthropoda|Insecta|Lepidoptera|Sphing...
# 1  Plantae|Tracheophyta|Magnoliopsida|Sapindales|...
# 2  Plantae|Tracheophyta|Magnoliopsida|Lamiales|Pl...
# 3  Plantae|Tracheophyta|Liliopsida|Poales|Poaceae...
# 4             Plantae|Tracheophyta|Magnoliopsida||||
#
#                                         common_names
# 0  Animals|Arthropods|Insects|Butterflies and Mot...
# 1  plants|vascular plants|dicots|soapberries, cas...
# 2  plants|vascular plants|dicots|mints, plantains...
# 3  plants|vascular plants|monocots|grasses, sedge...
# 4                  plants|vascular plants|dicots||||
#
# [5 rows x 28 columns]

# %%
def add_count_column(df, count_col):
    # count the number of taxon_id
    temp = df.copy()
    temp['temp_count'] = 1
    temp['temp_count'] = temp['temp_count'].astype(int)

    # create a df with 2 columns: taxon_id and temp_count       
    count_df = temp.groupby(['taxon_id'])['temp_count'].sum().reset_index()
    count_df.rename(columns={"temp_count": count_col}, inplace=True)

    df = df.merge(count_df)
    return df

def append_df(df):  
    #  try to match the species count that is shown on inaturalist project page     
    df['is_species'] = df['species'].notna()
    adjust_is_species_for_higher_ranks(df)  
        
    # count the number of observations for a taxon_id
    df = add_count_column(df, 'observations_count')
    return df

    
def add_row(row, rank, index):
    temp = {}
    temp['id'] = row['id']
    temp['taxon_id'] = row[rank + '_id']
    temp['common_name'] = row[rank + '_common_name']
    temp['scientific_name'] = row[rank]
    temp['user_login'] = row['user_login']
    temp['image_url'] = row['image_url']
    temp['rank'] = rank
    temp['taxon_ids'] = ('|').join(row['taxon_ids'].split('|')[0: index +1])
    temp['common_names'] = ('|').join(row['common_names'].split('|')[0: index+1])
    temp['scientific_names'] = ('|').join(row['scientific_names'].split('|')[0: index+1])
    return temp

def create_taxa_df(df):
    # create a new df with rows for each taxa and eac higher taxa
    new_rows = []
    for index, row in df.iterrows():
        for index, rank in enumerate(['kingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species']):
            if pd.isna(row[rank]):
                continue
                
            temp = add_row(row, rank, index)
            new_rows.append(temp)
            
    new_df =  pd.DataFrame(new_rows) 
    
    temp = df[['is_species', 'observations_count', 'taxon_id']].drop_duplicates()
    new_df['taxon_id'] = new_df['taxon_id'].astype(int)
    new_df = new_df.merge(temp, how='left')
    
    new_df.loc[new_df['observations_count'].isna(), 'observations_count'] = 0
    new_df['observations_count'] = new_df['observations_count'].astype(int)
     
    # count the total number of occurences for a taxa including higher taxa
    new_df = add_count_column(new_df, 'taxa_count')

    # sort newest observations first so that we get use the photo for the newest observations
    new_df = new_df.sort_values(['id'], ascending=False)
    new_df = new_df.drop_duplicates(subset=['taxon_id'])
    new_df = new_df.sort_values(['taxa_count'], ascending=False)
    
    return new_df



# try to match the species count that is shown on inaturalist project page   
# if a rank higher than species is the lowest occurence of the taxa, it is treated as
# a species. e.g. if there are no species for genus AA, genus AA 'is_species' is True 
def adjust_is_species_for_higher_ranks(df):
    adjust_is_species_for_rank(df, 'genus')    
    adjust_is_species_for_rank(df, 'family')   
    adjust_is_species_for_rank(df, 'order')  
    adjust_is_species_for_rank(df, 'class')  
    adjust_is_species_for_rank(df, 'phylum')    
    adjust_is_species_for_rank(df, 'kingdom') 
    df.loc[df['scientific_name'].str.contains(' × ') == True, 'is_species'] = True

def adjust_is_species_for_rank(df, rank):
    tmp = df.copy()
    taxa = list(df[df['is_species'] == True][rank].unique())
    tmp = tmp[(tmp['is_species'] == False) & (tmp[rank].notna())]
    for index, row in tmp[~ tmp[rank].isin(taxa)].iterrows():
        df.at[index, 'is_species'] = True

# %%
# combine multiple observations csvs for a project into one json         

for dir_path in Path().glob('../data/**/'):
    if dir_path.name != 'data':
        dfs = []
        for file_path in  Path().glob('../data/' +  dir_path.name + '/observations-*.csv'  ):
            print(file_path)
            cols = ['taxon_id', 'user_login', 'image_url', 'id']
            df = pd.read_csv(file_path, usecols=cols)
            df = df.dropna(subset=['taxon_id'])
            df['taxon_id'] = df['taxon_id'].astype(int)
            df = df.merge(inat_names_df, on="taxon_id", how="left")
                                    
            dfs.append(df)


        combine_df = pd.concat(dfs)        
        adjust_df = append_df(combine_df)
        taxa_df = create_taxa_df(adjust_df)

        new_path = Path('..','inat_data_explorer', 'src', 'lib', 'data') /dir_path.name
        new_path.mkdir(parents=True, exist_ok=True)
        taxa_df.to_json(new_path/ "taxa.json", orient = "records")
# Out:
# ../data/clarkstown-high-school-north/observations-200303.csv
# ../data/cedar-creek-reserve/observations-199064.csv
# ../data/los-angeles-bioblitz/observations-190446.csv
# ../data/ciencia-ciudadana-peru-bats/observations-199065.csv
# ../data/ciencia-ciudadana-peru-bees/observations-199066.csv

# %% [markdown]
# # create taxa json for LA indicator species

# %%
taxa_file = '../data/los-angeles-bioblitz/indicator_species.tsv'

indicator_cols = [ 'type', 'taxon_group', 'taxon_id']
df = pd.read_csv(taxa_file, sep='\t',  usecols=indicator_cols)
log_df(df)
# Out:
# (38, 3)
#   taxon_group                       type  taxon_id
# 0       Birds  Park/Natural Area Species      1409
# 1       Birds  Park/Natural Area Species      1986
# 2       Birds    Stream/Riparian Species      4956
# 3       Birds       Neighborhood Species      5212
# 4       Birds    Stream/Riparian Species      7109

# %%
observation_file = '../data/los-angeles-bioblitz/observations-190446.csv'
df2 = pd.read_csv(observation_file, dtype=str, usecols=cols)
df2 = df2.dropna(subset=['taxon_id'])
log_df(df2)
# Out:
# (14838, 13)
#       user_login                                          image_url  \
# 0  gardenchris01  https://inaturalist-open-data.s3.amazonaws.com...
# 1      amyeweiss  https://static.inaturalist.org/photos/13460686...
# 2        jklabin  https://static.inaturalist.org/photos/13463191...
# 3        jklabin  https://static.inaturalist.org/photos/13463220...
# 4        jklabin  https://static.inaturalist.org/photos/13463623...
#
#      scientific_name                               common_name  \
# 0      Nyctaginaceae                       four o'clock family
# 1  Metaltella simoni  South American Toothed Hacklemesh Weaver
# 2      Canis latrans                                    Coyote
# 3  Buteo jamaicensis                           Red-tailed Hawk
# 4  Buteo jamaicensis                           Red-tailed Hawk
#
#   iconic_taxon_name taxon_id taxon_kingdom_name taxon_phylum_name  \
# 0           Plantae    50256            Plantae      Tracheophyta
# 1         Arachnida   224975           Animalia        Arthropoda
# 2          Mammalia    42051           Animalia          Chordata
# 3              Aves     5212           Animalia          Chordata
# 4              Aves     5212           Animalia          Chordata
#
#   taxon_class_name taxon_order_name taxon_family_name taxon_genus_name  \
# 0    Magnoliopsida   Caryophyllales     Nyctaginaceae              NaN
# 1        Arachnida          Araneae           Desidae       Metaltella
# 2         Mammalia        Carnivora           Canidae            Canis
# 3             Aves  Accipitriformes      Accipitridae            Buteo
# 4             Aves  Accipitriformes      Accipitridae            Buteo
#
#   taxon_species_name
# 0                NaN
# 1  Metaltella simoni
# 2      Canis latrans
# 3  Buteo jamaicensis
# 4  Buteo jamaicensis

# %%
inat_names_cols =['taxon_id', 'scientific_names', 'common_names', 'taxon_ids']
inat_names_df = pd.read_csv(all_taxa, dtype=str, usecols=inat_names_cols)
inat_names_df['taxon_id'] = inat_names_df['taxon_id'].astype(int)
inat_names_df = inat_names_df.fillna('')
log_df(inat_names_df)
# Out:
# (3851, 4)
#    taxon_id                                   taxon_ids  \
# 0    143452     1|47120|47158|47157|47213|143454|143452
# 1     47727       47126|211194|47124|47729|58321|47727|
# 2     53178  47126|211194|47124|48151|50638|50636|53178
# 3     60307  47126|211194|47163|47162|47434|52809|60307
# 4     47124                      47126|211194|47124||||
#
#                                     scientific_names  \
# 0  Animalia|Arthropoda|Insecta|Lepidoptera|Sphing...
# 1  Plantae|Tracheophyta|Magnoliopsida|Sapindales|...
# 2  Plantae|Tracheophyta|Magnoliopsida|Lamiales|Pl...
# 3  Plantae|Tracheophyta|Liliopsida|Poales|Poaceae...
# 4             Plantae|Tracheophyta|Magnoliopsida||||
#
#                                         common_names
# 0  Animals|Arthropods|Insects|Butterflies and Mot...
# 1  plants|vascular plants|dicots|soapberries, cas...
# 2  plants|vascular plants|dicots|mints, plantains...
# 3  plants|vascular plants|monocots|grasses, sedge...
# 4                  plants|vascular plants|dicots||||

# %%
taxa_df = create_taxa_df(df2)
log_df(taxa_df)
# Out:
# (2775, 15)
#           user_login                                          image_url  \
# 159  reese_bernstein  https://inaturalist-open-data.s3.amazonaws.com...
# 227  naturephotosuze  https://static.inaturalist.org/photos/13499159...
# 166          kikster  https://inaturalist-open-data.s3.amazonaws.com...
# 3            jklabin  https://static.inaturalist.org/photos/13463220...
# 4            jklabin  https://static.inaturalist.org/photos/13463649...
#
#              scientific_name           common_name iconic_taxon_name  \
# 159  Sceloporus occidentalis  Western Fence Lizard          Reptilia
# 227     Haemorhous mexicanus           House Finch              Aves
# 166         Danaus plexippus               Monarch           Insecta
# 3          Buteo jamaicensis       Red-tailed Hawk              Aves
# 4           Zenaida macroura         Mourning Dove              Aves
#
#      taxon_id taxon_kingdom_name taxon_phylum_name taxon_class_name  \
# 159     36204           Animalia          Chordata         Reptilia
# 227    199840           Animalia          Chordata             Aves
# 166     48662           Animalia        Arthropoda          Insecta
# 3        5212           Animalia          Chordata             Aves
# 4        3454           Animalia          Chordata             Aves
#
#     taxon_order_name taxon_family_name taxon_genus_name  \
# 159         Squamata   Phrynosomatidae       Sceloporus
# 227    Passeriformes      Fringillidae       Haemorhous
# 166      Lepidoptera       Nymphalidae           Danaus
# 3    Accipitriformes      Accipitridae            Buteo
# 4      Columbiformes        Columbidae          Zenaida
#
#           taxon_species_name  is_species  count
# 159  Sceloporus occidentalis        True    342
# 227     Haemorhous mexicanus        True    146
# 166         Danaus plexippus        True    144
# 3          Buteo jamaicensis        True    140
# 4           Zenaida macroura        True    126

# %%
taxa_df = taxa_df.merge(inat_names_df, on="taxon_id", how="left")
log_df(taxa_df)
# Out:
# (2775, 18)
#         user_login                                          image_url  \
# 0  reese_bernstein  https://inaturalist-open-data.s3.amazonaws.com...
# 1  naturephotosuze  https://static.inaturalist.org/photos/13499159...
# 2          kikster  https://inaturalist-open-data.s3.amazonaws.com...
# 3          jklabin  https://static.inaturalist.org/photos/13463220...
# 4          jklabin  https://static.inaturalist.org/photos/13463649...
#
#            scientific_name           common_name iconic_taxon_name  taxon_id  \
# 0  Sceloporus occidentalis  Western Fence Lizard          Reptilia     36204
# 1     Haemorhous mexicanus           House Finch              Aves    199840
# 2         Danaus plexippus               Monarch           Insecta     48662
# 3        Buteo jamaicensis       Red-tailed Hawk              Aves      5212
# 4         Zenaida macroura         Mourning Dove              Aves      3454
#
#   taxon_kingdom_name taxon_phylum_name taxon_class_name taxon_order_name  \
# 0           Animalia          Chordata         Reptilia         Squamata
# 1           Animalia          Chordata             Aves    Passeriformes
# 2           Animalia        Arthropoda          Insecta      Lepidoptera
# 3           Animalia          Chordata             Aves  Accipitriformes
# 4           Animalia          Chordata             Aves    Columbiformes
#
#   taxon_family_name taxon_genus_name       taxon_species_name  is_species  \
# 0   Phrynosomatidae       Sceloporus  Sceloporus occidentalis        True
# 1      Fringillidae       Haemorhous     Haemorhous mexicanus        True
# 2       Nymphalidae           Danaus         Danaus plexippus        True
# 3      Accipitridae            Buteo        Buteo jamaicensis        True
# 4        Columbidae          Zenaida         Zenaida macroura        True
#
#    count                              taxon_ids  \
# 0    342      1|2|26036|26172|36074|36141|36204
# 1    146          1|2|3|7251|9079|199910|199840
# 2    144  1|47120|47158|47157|47922|48663|48662
# 3    140             1|2|3|71261|5067|5179|5212
# 4    126              1|2|3|2708|2715|3438|3454
#
#                                     scientific_names  \
# 0  Animalia|Chordata|Reptilia|Squamata|Phrynosoma...
# 1  Animalia|Chordata|Aves|Passeriformes|Fringilli...
# 2  Animalia|Arthropoda|Insecta|Lepidoptera|Nympha...
# 3  Animalia|Chordata|Aves|Accipitriformes|Accipit...
# 4  Animalia|Chordata|Aves|Columbiformes|Columbida...
#
#                                         common_names
# 0  Animals|Chordates|Reptiles|Snakes and Lizards|...
# 1  Animals|Chordates|Birds|Perching Birds|Finches...
# 2  Animals|Arthropods|Insects|Butterflies and Mot...
# 3  Animals|Chordates|Birds|Hawks, Eagles, Kites, ...
# 4  Animals|Chordates|Birds|Pigeons and Doves|Pige...

# %%
taxa_df = df.merge(taxa_df, how="outer")
taxa_df['count'].fillna(0, inplace=True)
taxa_df['count'] = taxa_df['count'].astype(int)
taxa_df = taxa_df.sort_values('count', ascending=False)
log_df(taxa_df)
# Out:
# (2785, 20)
#       taxon_group                  type  taxon_id       user_login  \
# 38            NaN                   NaN     36204  reese_bernstein
# 39            NaN                   NaN    199840  naturephotosuze
# 20  Invertebrates  Neighborhood Species     48662          kikster
# 3           Birds  Neighborhood Species      5212          jklabin
# 40            NaN                   NaN      3454          jklabin
#
#                                             image_url  \
# 38  https://inaturalist-open-data.s3.amazonaws.com...
# 39  https://static.inaturalist.org/photos/13499159...
# 20  https://inaturalist-open-data.s3.amazonaws.com...
# 3   https://static.inaturalist.org/photos/13463220...
# 40  https://static.inaturalist.org/photos/13463649...
#
#             scientific_name           common_name iconic_taxon_name  \
# 38  Sceloporus occidentalis  Western Fence Lizard          Reptilia
# 39     Haemorhous mexicanus           House Finch              Aves
# 20         Danaus plexippus               Monarch           Insecta
# 3         Buteo jamaicensis       Red-tailed Hawk              Aves
# 40         Zenaida macroura         Mourning Dove              Aves
#
#    taxon_kingdom_name taxon_phylum_name taxon_class_name taxon_order_name  \
# 38           Animalia          Chordata         Reptilia         Squamata
# 39           Animalia          Chordata             Aves    Passeriformes
# 20           Animalia        Arthropoda          Insecta      Lepidoptera
# 3            Animalia          Chordata             Aves  Accipitriformes
# 40           Animalia          Chordata             Aves    Columbiformes
#
#    taxon_family_name taxon_genus_name       taxon_species_name is_species  \
# 38   Phrynosomatidae       Sceloporus  Sceloporus occidentalis       True
# 39      Fringillidae       Haemorhous     Haemorhous mexicanus       True
# 20       Nymphalidae           Danaus         Danaus plexippus       True
# 3       Accipitridae            Buteo        Buteo jamaicensis       True
# 40        Columbidae          Zenaida         Zenaida macroura       True
#
#     count                              taxon_ids  \
# 38    342      1|2|26036|26172|36074|36141|36204
# 39    146          1|2|3|7251|9079|199910|199840
# 20    144  1|47120|47158|47157|47922|48663|48662
# 3     140             1|2|3|71261|5067|5179|5212
# 40    126              1|2|3|2708|2715|3438|3454
#
#                                      scientific_names  \
# 38  Animalia|Chordata|Reptilia|Squamata|Phrynosoma...
# 39  Animalia|Chordata|Aves|Passeriformes|Fringilli...
# 20  Animalia|Arthropoda|Insecta|Lepidoptera|Nympha...
# 3   Animalia|Chordata|Aves|Accipitriformes|Accipit...
# 40  Animalia|Chordata|Aves|Columbiformes|Columbida...
#
#                                          common_names
# 38  Animals|Chordates|Reptiles|Snakes and Lizards|...
# 39  Animals|Chordates|Birds|Perching Birds|Finches...
# 20  Animals|Arthropods|Insects|Butterflies and Mot...
# 3   Animals|Chordates|Birds|Hawks, Eagles, Kites, ...
# 40  Animals|Chordates|Birds|Pigeons and Doves|Pige...

# %% [markdown]
# ### connect to inat api to get data for indicator species with no observations

# %%
for index, row in taxa_df[taxa_df['user_login'].isna()].iterrows():
    response = requests.get(f'https://api.inaturalist.org/v1/taxa/{row["taxon_id"]}')
    if response.status_code == 200:
        json_data = response.json()['results'][0]
        
        result = {
            'scientific_name': json_data['name'], 
            'common_name': json_data['preferred_common_name'],
            'image_url': json_data['default_photo']['medium_url'],
            'user_login':  json_data['default_photo']['attribution'],
        }

        for taxon in json_data['ancestors']:
            if taxon['rank'] == 'kingdom':
                result['taxon_kingdom_name'] = taxon['name']
            elif taxon['rank'] == 'phylum':
                result['taxon_phylum_name'] = taxon['name']
            elif taxon['rank'] == 'class':
                result['taxon_class_name'] = taxon['name']
            elif taxon['rank'] == 'order':
                result['taxon_order_name'] = taxon['name']
            elif taxon['rank'] == 'family':
                result['taxon_family_name'] = taxon['name']
            elif taxon['rank'] == 'genus':
                result['taxon_genus_name'] = taxon['name']
            elif taxon['rank'] == 'species':
                result['taxon_species_name'] = taxon['name']
                
        if json_data['rank'] == 'kingdom':
            result['taxon_kingdom_name'] = json_data['name']
        elif json_data['rank'] == 'phylum':
            result['taxon_phylum_name'] = json_data['name']
        elif json_data['rank'] == 'class':
            result['taxon_class_name'] = json_data['name']
        elif json_data['rank'] == 'order':
            result['taxon_order_name'] = json_data['name']
        elif json_data['rank'] == 'family':
            result['taxon_family_name'] = json_data['name']
        elif json_data['rank'] == 'genus':
            result['taxon_genus_name'] = json_data['name']
        elif json_data['rank'] == 'species':
            result['taxon_species_name'] = json_data['name']
            
            
        for col in result:
            taxa_df.at[index, col] = result[col]

# %%
taxa_list_path = Path('..', 'data',  'los-angeles-bioblitz', 'taxa_list.csv' )
taxa_df.to_csv(taxa_list_path, index=False)

new_path = Path('..','inat_data_explorer', 'src', 'lib', 'data', 'los-angeles-bioblitz')
new_path.mkdir(parents=True, exist_ok=True)
basic_df = taxa_df[basic_cols + ['taxon_group', 'type', 'count', 'is_species', 'taxon_ids', 'scientific_names', 'common_names']]
basic_df.to_json(new_path/ 'taxa.json', orient = "records")

# %% [markdown]
# # create  a list of all taxa ids for a project

# %%
path = '../data/clarkstown-high-school-north/observations-200303.csv'

cols = [
    'taxon_id', 'user_login', 'image_url', 'id',
    # 'taxon_species_name',
    # 'taxon_genus_name', 'taxon_family_name', 'taxon_order_name',
    # 'taxon_class_name','taxon_phylum_name','taxon_kingdom_name',
    # 'scientific_name',
    
]
df = pd.read_csv(path, dtype=str, usecols=cols)
df = df.dropna(subset=['taxon_id'])
log_df(df)
# Out:
# (1077, 4)
#         id   user_login                                          image_url  \
# 0  1551812     lgertzer  https://inaturalist-open-data.s3.amazonaws.com...
# 1  1556119  mcgovernm97  https://inaturalist-open-data.s3.amazonaws.com...
# 2  1556120  mcgovernm97  https://inaturalist-open-data.s3.amazonaws.com...
# 3  1556121  mcgovernm97  https://inaturalist-open-data.s3.amazonaws.com...
# 4  1556122  mcgovernm97  https://inaturalist-open-data.s3.amazonaws.com...
#
#   taxon_id
# 0   143452
# 1    47727
# 2    53178
# 3    60307
# 4    47124

# %%
columns = []
ranks = ['kingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species']
[columns.append(rank + '_id') for rank in ranks]
[columns.append(rank + '_common_name') for rank in ranks]
columns = ['taxon_id', 'scientific_name', 'common_name', 'rank'] + ranks + columns 

inat_names_df = pd.read_csv(all_taxa, dtype=str, usecols=columns)
log_df(inat_names_df)
# Out:
# (3851, 25)
#        scientific_name         common_name taxon_id   kingdom        phylum  \
# 0  Deidamia inscriptum     Lettered Sphinx   143452  Animalia    Arthropoda
# 1                 Acer              maples    47727   Plantae  Tracheophyta
# 2  Plantago lanceolata    ribwort plantain    53178   Plantae  Tracheophyta
# 3        Poa pratensis  Kentucky bluegrass    60307   Plantae  Tracheophyta
# 4        Magnoliopsida              dicots    47124   Plantae  Tracheophyta
#
#            class        order          family     genus              species  \
# 0        Insecta  Lepidoptera      Sphingidae  Deidamia  Deidamia inscriptum
# 1  Magnoliopsida   Sapindales     Sapindaceae      Acer                  NaN
# 2  Magnoliopsida     Lamiales  Plantaginaceae  Plantago  Plantago lanceolata
# 3     Liliopsida       Poales         Poaceae       Poa        Poa pratensis
# 4  Magnoliopsida          NaN             NaN       NaN                  NaN
#
#    ... phylum_id phylum_common_name class_id class_common_name order_id  \
# 0  ...     47120         Arthropods    47158           Insects    47157
# 1  ...    211194    vascular plants    47124            dicots    47729
# 2  ...    211194    vascular plants    47124            dicots    48151
# 3  ...    211194    vascular plants    47163          monocots    47162
# 4  ...    211194    vascular plants    47124            dicots      NaN
#
#                               order_common_name family_id family_common_name  \
# 0                         Butterflies and Moths     47213       Sphinx Moths
# 1  soapberries, cashews, mahoganies, and allies     58321   soapberry family
# 2          mints, plantains, olives, and allies     50638    plantain family
# 3         grasses, sedges, cattails, and allies     47434            grasses
# 4                                           NaN       NaN                NaN
#
#   genus_id genus_common_name
# 0   143454               NaN
# 1    47727            maples
# 2    50636          plantain
# 3    52809    Meadow-grasses
# 4      NaN               NaN
#
# [5 rows x 25 columns]

# %%
merge_df = df.merge(inat_names_df, how='left', on='taxon_id')
adjust_df = append_df(merge_df)
new_df = create_taxa_df(adjust_df)
# Out:
# (1077, 28)
#         id   user_login                                          image_url  \
# 0  1551812     lgertzer  https://inaturalist-open-data.s3.amazonaws.com...
# 1  1556119  mcgovernm97  https://inaturalist-open-data.s3.amazonaws.com...
# 2  1556120  mcgovernm97  https://inaturalist-open-data.s3.amazonaws.com...
# 3  1556121  mcgovernm97  https://inaturalist-open-data.s3.amazonaws.com...
# 4  1556122  mcgovernm97  https://inaturalist-open-data.s3.amazonaws.com...
#
#   taxon_id      scientific_name         common_name   kingdom        phylum  \
# 0   143452  Deidamia inscriptum     Lettered Sphinx  Animalia    Arthropoda
# 1    47727                 Acer              maples   Plantae  Tracheophyta
# 2    53178  Plantago lanceolata    ribwort plantain   Plantae  Tracheophyta
# 3    60307        Poa pratensis  Kentucky bluegrass   Plantae  Tracheophyta
# 4    47124        Magnoliopsida              dicots   Plantae  Tracheophyta
#
#            class        order  ... phylum_id phylum_common_name class_id  \
# 0        Insecta  Lepidoptera  ...     47120         Arthropods    47158
# 1  Magnoliopsida   Sapindales  ...    211194    vascular plants    47124
# 2  Magnoliopsida     Lamiales  ...    211194    vascular plants    47124
# 3     Liliopsida       Poales  ...    211194    vascular plants    47163
# 4  Magnoliopsida          NaN  ...    211194    vascular plants    47124
#
#   class_common_name order_id                             order_common_name  \
# 0           Insects    47157                         Butterflies and Moths
# 1            dicots    47729  soapberries, cashews, mahoganies, and allies
# 2            dicots    48151          mints, plantains, olives, and allies
# 3          monocots    47162         grasses, sedges, cattails, and allies
# 4            dicots      NaN                                           NaN
#
#   family_id family_common_name genus_id genus_common_name
# 0     47213       Sphinx Moths   143454               NaN
# 1     58321   soapberry family    47727            maples
# 2     50638    plantain family    50636          plantain
# 3     47434            grasses    52809    Meadow-grasses
# 4       NaN                NaN      NaN               NaN
#
# [5 rows x 28 columns]

# %%
# Out:
#             id   user_login  \
# 0      1551812     lgertzer
# 1      1556119  mcgovernm97
# 2      3306988    rebeccab2
# 3     81561936      emilyd5
# 4      1556120  mcgovernm97
# ...        ...          ...
# 1072  81656257    moosty123
# 1073  81658816    moosty123
# 1074  81659440    moosty123
# 1075  83406604       kwadwo
# 1076  83431861    maxkahann
#
#                                               image_url taxon_id  \
# 0     https://inaturalist-open-data.s3.amazonaws.com...   143452
# 1     https://inaturalist-open-data.s3.amazonaws.com...    47727
# 2     https://inaturalist-open-data.s3.amazonaws.com...    47727
# 3     https://inaturalist-open-data.s3.amazonaws.com...    47727
# 4     https://inaturalist-open-data.s3.amazonaws.com...    53178
# ...                                                 ...      ...
# 1072  https://inaturalist-open-data.s3.amazonaws.com...     9915
# 1073  https://inaturalist-open-data.s3.amazonaws.com...  1097013
# 1074  https://inaturalist-open-data.s3.amazonaws.com...    50863
# 1075  https://inaturalist-open-data.s3.amazonaws.com...    52989
# 1076  https://inaturalist-open-data.s3.amazonaws.com...    53435
#
#           scientific_name            common_name   kingdom        phylum  \
# 0     Deidamia inscriptum        Lettered Sphinx  Animalia    Arthropoda
# 1                    Acer                 maples   Plantae  Tracheophyta
# 2                    Acer                 maples   Plantae  Tracheophyta
# 3                    Acer                 maples   Plantae  Tracheophyta
# 4     Plantago lanceolata       ribwort plantain   Plantae  Tracheophyta
# ...                   ...                    ...       ...           ...
# 1072        Piranga rubra         Summer Tanager  Animalia      Chordata
# 1073       Schizomantodea                    NaN  Animalia    Arthropoda
# 1074          Chlorophyta            green algae   Plantae   Chlorophyta
# 1075      Cirsium vulgare           Bull Thistle   Plantae  Tracheophyta
# 1076     Ribes sanguineum  Red-flowering Currant   Plantae  Tracheophyta
#
#               class          order  ... class_id class_common_name order_id  \
# 0           Insecta    Lepidoptera  ...    47158           Insects    47157
# 1     Magnoliopsida     Sapindales  ...    47124            dicots    47729
# 2     Magnoliopsida     Sapindales  ...    47124            dicots    47729
# 3     Magnoliopsida     Sapindales  ...    47124            dicots    47729
# 4     Magnoliopsida       Lamiales  ...    47124            dicots    48151
# ...             ...            ...  ...      ...               ...      ...
# 1072           Aves  Passeriformes  ...        3             Birds     7251
# 1073        Insecta       Mantodea  ...    47158           Insects    48112
# 1074            NaN            NaN  ...      NaN               NaN      NaN
# 1075  Magnoliopsida      Asterales  ...    47124            dicots    47605
# 1076  Magnoliopsida   Saxifragales  ...    47124            dicots    71289
#
#                                     order_common_name family_id  \
# 0                               Butterflies and Moths     47213
# 1        soapberries, cashews, mahoganies, and allies     58321
# 2        soapberries, cashews, mahoganies, and allies     58321
# 3        soapberries, cashews, mahoganies, and allies     58321
# 4                mints, plantains, olives, and allies     50638
# ...                                               ...       ...
# 1072                                   Perching Birds     71305
# 1073                                         Mantises       NaN
# 1074                                              NaN       NaN
# 1075  sunflowers, bellflowers, fanflowers, and allies     47604
# 1076               saxifrages, stonecrops, and allies     47131
#
#                            family_common_name genus_id  \
# 0                                Sphinx Moths   143454
# 1                            soapberry family    47727
# 2                            soapberry family    47727
# 3                            soapberry family    47727
# 4                             plantain family    50636
# ...                                       ...      ...
# 1072                     Cardinals and Allies     9913
# 1073                                      NaN      NaN
# 1074                                      NaN      NaN
# 1075  sunflowers, daisies, asters, and allies    48561
# 1076                        Gooseberry Family    47130
#
#               genus_common_name is_species observations_count
# 0                           NaN       True                  1
# 1                        maples      False                  3
# 2                        maples      False                  3
# 3                        maples      False                  3
# 4                      plantain       True                  8
# ...                         ...        ...                ...
# 1072           Piranga Tanagers       True                  1
# 1073                        NaN       True                  1
# 1074                        NaN       True                  1
# 1075                   thistles       True                  1
# 1076  currants and gooseberries       True                  1
#
# [1077 rows x 30 columns]

# %%
new_df = create_taxa_df(adjust_df)


new_df
# Out:
#             id taxon_id        common_name   scientific_name  user_login  \
# 790   83683271    47126             plants           Plantae    leo25097
# 1406  83431868   211194    vascular plants      Tracheophyta   maxkahann
# 2019  83431868    47124             dicots     Magnoliopsida   maxkahann
# 181   83431860        1            Animals          Animalia   maxkahann
# 2916  83431860        2          Chordates          Chordata   maxkahann
# ...        ...      ...                ...               ...         ...
# 6177  48148609    50790    common toadflax  Linaria vulgaris   kylasevim
# 6184  48151853    55844  lesser periwinkle       Vinca minor   matthewc6
# 6195  48154700    39771     Painted Turtle   Chrysemys picta  sarahb2449
# 6194  48154700    39770    Painted Turtles         Chrysemys  sarahb2449
# 5626  13117194    60132   creeping thistle   Cirsium arvense      ryant5
#
#                                               image_url     rank is_species  \
# 790   https://inaturalist-open-data.s3.amazonaws.com...  kingdom      False
# 1406  https://inaturalist-open-data.s3.amazonaws.com...   phylum      False
# 2019  https://inaturalist-open-data.s3.amazonaws.com...    class      False
# 181   https://inaturalist-open-data.s3.amazonaws.com...  kingdom        NaN
# 2916  https://inaturalist-open-data.s3.amazonaws.com...   phylum        NaN
# ...                                                 ...      ...        ...
# 6177  https://inaturalist-open-data.s3.amazonaws.com...  species       True
# 6184  https://inaturalist-open-data.s3.amazonaws.com...  species       True
# 6195  https://inaturalist-open-data.s3.amazonaws.com...  species        NaN
# 6194  https://inaturalist-open-data.s3.amazonaws.com...    genus        NaN
# 5626  https://inaturalist-open-data.s3.amazonaws.com...  species       True
#
#       observations_count  taxa_count
# 790                   31         666
# 1406                  11         618
# 2019                  45         498
# 181                    0         372
# 2916                   0         204
# ...                  ...         ...
# 6177                   1           1
# 6184                   1           1
# 6195                   0           1
# 6194                   0           1
# 5626                   1           1
#
# [774 rows x 10 columns]
